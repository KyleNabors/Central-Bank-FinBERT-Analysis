# %%
import requests
from bs4 import BeautifulSoup
import os
import re
import pandas as pd
from PyPDF2 import PdfReader
from urllib.parse import urljoin
import pdfkit  # For converting .htm to .pdf

# Directories
pdf_dir = "/Users/kylenabors/Documents/Database/Training Data/japan/japan_speeches/PDFs"
csv_path = "/Users/kylenabors/Documents/Database/Training Data/Japan/japan_speeches/japan_speeches.csv"

# Create the PDF directory if it doesn't exist
if not os.path.exists(pdf_dir):
    os.makedirs(pdf_dir)

# Base URLs
current_base_url = "https://www.boj.or.jp"
archive_base_url = "https://www2.boj.or.jp"

# Define the range of years you want to scrape
start_year = 1999  # Adjust the start year as needed
end_year = 2024  # Adjust the end year as needed
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)"
    " Chrome/98.0.4758.102 Safari/537.36"
}

speech_urls = []

# Generate per-year speech URLs
year_urls = []
for year in range(start_year, end_year + 1):
    if year >= 2011:
        year_url = f"{current_base_url}/en/about/press/koen_{year}/index.htm"
    else:
        if year >= 1999:
            year_url = f"{archive_base_url}/archive/en/announcements/press/koen_{year}/index.htm"
        else:
            continue  # Skip years before 2003 if not available
    year_urls.append((year, year_url))

print(f"Found {len(year_urls)} year URLs.")

# Step 2: Iterate over each year's page to collect speech URLs
for year, year_url in year_urls:
    print(f"Processing year URL: {year_url}")
    response = requests.get(year_url)
    if response.status_code != 200:
        print(f"Failed to retrieve {year_url}, status code {response.status_code}")
        continue
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the speech table
    table = soup.find("table", class_="js-tbl")
    if not table:
        # For archive pages, the table might not have the same class
        table = soup.find("table")
        if not table:
            print(f"No speech table found on page {year_url}")
            continue

    # Extract rows from the table
    tbody = table.find("tbody")
    if not tbody:
        # For archive pages, there might be no <tbody>
        rows = table.find_all("tr")
    else:
        rows = tbody.find_all("tr")

    for row in rows:
        cols = row.find_all("td")
        if len(cols) >= 2:
            date_col = cols[0].get_text(strip=True)
            # For archive pages, the speaker might be missing
            if year >= 2011 and len(cols) >= 3:
                speaker_col = cols[1].get_text(strip=True)
                title_col = cols[2]
            else:
                speaker_col = ""
                title_col = cols[1]

            # Extract the link to the speech page
            link = title_col.find("a", href=True)
            if link:
                speech_url = urljoin(year_url, link["href"])
                title = link.get_text(strip=True)
                speech_urls.append(
                    {
                        "date": date_col,
                        "speaker": speaker_col,
                        "title": title,
                        "speech_url": speech_url,
                    }
                )

    print(f"Processed speeches from {year_url}")

print(f"Total number of speeches found: {len(speech_urls)}")

# Remove duplicates if any
speech_urls = [dict(t) for t in {tuple(d.items()) for d in speech_urls}]

# Read existing CSV data (if any)
if os.path.exists(csv_path) and os.path.getsize(csv_path) > 0:
    existing_df = pd.read_csv(csv_path)
    if "speech_url" in existing_df.columns:
        existing_speech_urls = set(existing_df["speech_url"])
    else:
        existing_speech_urls = set()
else:
    existing_df = pd.DataFrame()
    existing_speech_urls = set()

speech_data = []

for idx, speech in enumerate(speech_urls):
    speech_url = speech["speech_url"]

    # Skip if speech already processed
    if speech_url in existing_speech_urls:
        print(f"Already processed speech at {speech_url}, skipping.")
        continue

    print(f"Processing speech {idx + 1}/{len(speech_urls)}: {speech_url}")

    response = requests.get(speech_url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve {speech_url}, status code {response.status_code}")
        continue
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all PDF links on the page

    pdf_links = soup.find_all("a", href=re.compile(r"\.pdf$"))
    htm_links = soup.find_all("a", href=re.compile(r"\.htm$"))

    pdf_links.extend(htm_links)

    if pdf_links:
        # Try to find a link that includes 'Full Text' in its text
        pdf_link_tag = None
        for link in pdf_links:
            link_text = link.get_text(strip=True)
            if (
                "Full Text" in link_text
                or "full text" in link_text
                or "Full text" in link_text
            ):
                pdf_link_tag = link
                break
        # If no 'Full Text' link is found, use the first PDF link
        if not pdf_link_tag:
            pdf_link_tag = pdf_links[0]
            print(f"Using first available PDF link for speech at {speech_url}")

        pdf_href = pdf_link_tag["href"]
        # Adjust base URL if necessary
        if speech_url.startswith(archive_base_url):
            pdf_url = urljoin(archive_base_url, pdf_href)
        else:
            pdf_url = urljoin(speech_url, pdf_href)
        print(f"Found PDF URL: {pdf_url}")  # Logging the PDF URL
        pdf_filename = pdf_url.split("/")[-1]
        pdf_path = os.path.join(pdf_dir, pdf_filename)

        # Download the PDF if not already downloaded
        if not os.path.exists(pdf_path):
            if pdf_url.endswith(".htm"):
                pdfkit.from_url(pdf_url, pdf_path)
            try:
                pdf_response = requests.get(pdf_url, headers=headers)
                pdf_response.raise_for_status()  # Check for HTTP errors
                with open(pdf_path, "wb") as f:
                    f.write(pdf_response.content)
                print(f"Downloaded PDF: {pdf_filename}")

            except Exception as e:
                print(f"Error downloading PDF {pdf_filename}: {e}")
                text = ""
                continue  # Skip to the next speech
        else:
            print(f"PDF {pdf_filename} already downloaded.")

        # Extract text from the PDF
        try:
            with open(pdf_path, "rb") as f:
                reader = PdfReader(f)
                text = ""
                for page in reader.pages:
                    page_text = page.extract_text()
                    if page_text:
                        text += page_text
        except Exception as e:
            print(f"Error reading PDF {pdf_filename}: {e}")
            text = ""
    else:
        print(f"No PDF links found for speech at {speech_url}")
        # Attempt to extract text from the web page
        content_div = soup.find("div", id="contents")
        if not content_div:
            content_div = soup.find("div", id="content")  # Try alternative IDs
        if content_div:
            # Remove unwanted elements
            for unwanted in content_div(
                ["script", "style", "noscript", "header", "footer"]
            ):
                unwanted.decompose()
            text = content_div.get_text(separator="\n", strip=True)
        else:
            text = ""
            print(f"Could not extract text from the web page at {speech_url}")

    # Append data
    speech_data.append(
        {
            "date": speech["date"],
            "speaker": speech["speaker"],
            "title": speech["title"],
            "speech_url": speech_url,
            "text": text,
        }
    )

# Combine new data with existing data and save to CSV
new_df = pd.DataFrame(speech_data)
if not existing_df.empty:
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)
else:
    combined_df = new_df

# Save to CSV
combined_df.to_csv(csv_path, index=False)
print(f"CSV file updated at {csv_path}")
# Out:
# Found 26 year URLs.
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/index.htm
# Processing year URL: https://www2.boj.or.jp/archive/en/announcements/press/koen_2010/index.htm
# Processed speeches from https://www2.boj.or.jp/archive/en/announcements/press/koen_2010/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2011/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2011/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2012/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2012/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2013/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2013/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2014/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2014/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2015/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2015/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2016/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2016/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2017/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2017/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2018/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2018/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2019/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2019/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2020/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2020/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2021/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2021/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2022/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2022/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2023/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2023/index.htm
# Processing year URL: https://www.boj.or.jp/en/about/press/koen_2024/index.htm
# Processed speeches from https://www.boj.or.jp/en/about/press/koen_2024/index.htm
# Total number of speeches found: 729
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161012a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0805b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170308a.htm, skipping.
# Processing speech 4/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0905d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0905d.pdf
# Error downloading PDF ko0905d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0905d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170502a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141202a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230519a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0308a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181016a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171204a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120726a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130613a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190801a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150928a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170609a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220423a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170209a.htm, skipping.
# Processing speech 18/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0802b.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0802b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0802b.pdf
# Error downloading PDF ko0802b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0802b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181026a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131125a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230925a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191004a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0405a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140723a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0802a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0601a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190712a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9907a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140910a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130412a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0306c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160513a.htm, skipping.
# Processing speech 33/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0809e.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0809e.pdf
# Error downloading PDF ko0809e.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0809e.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150309a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120404a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160303a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240306b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120422a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140319c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171004a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130920a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko231106a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160609a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110628a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0004a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211005a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140529a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140912a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0802c.pdf, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161209a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230802a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190117c.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0304b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240919a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141105a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko231206a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170726a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240312a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131126a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190912a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0806a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120306a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121012b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0409a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9907c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111128a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171005a.htm, skipping.
# Processing speech 68/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0911d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0911d.pdf
# Error downloading PDF ko0911d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0911d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140322a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120217a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190304a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230629a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0003a.htm, skipping.
# Processing speech 74/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0908c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0908c.pdf
# Error downloading PDF ko0908c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0908c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110930c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120422b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200828a.htm, skipping.
# Processing speech 78/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0907a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0907a.pdf
# Error downloading PDF ko0907a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0907a.pdf
# Processing speech 79/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0808a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0808a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0808a.pdf
# Error downloading PDF ko0808a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0808a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171019a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180131a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221226a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130524a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140603a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210325a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240703a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110223a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170111a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0107b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0805a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230306a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240828a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709d.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0704a.pdf, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211201a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170223a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200514a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190607b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko231206b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210330a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210608a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160317a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191128b.htm, skipping.
# Processing speech 104/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0908d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0908d.pdf
# Error downloading PDF ko0908d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0908d.pdf
# Processing speech 105/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0903d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0903d.pdf
# Error downloading PDF ko0903d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0903d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140327a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151207b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151203a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210831a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131010a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0604b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121203b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150123a.htm, skipping.
# Processing speech 114/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0404c.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0404c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0404c.pdf
# Error downloading PDF ko0404c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0404c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150227a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko231225a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181130a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200306a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141125c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171102a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0512c.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0202a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220926a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140829a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220413b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709e.htm, skipping.
# Processing speech 127/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0808c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0808c.pdf
# Error downloading PDF ko0808c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0808c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131015a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190117b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0312a.htm, skipping.
# Processing speech 131/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0902b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0902b.pdf
# Error downloading PDF ko0902b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0902b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220216a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110526a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180302a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200910a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0805c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121126a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140619b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0501b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121012c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171117a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0710a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220329b.htm, skipping.
# Processing speech 144/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0312d.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0312d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0312d.pdf
# Error downloading PDF ko0312d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0312d.pdf
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0509b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171101a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0006a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220606a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240423a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0309a.htm, skipping.
# Processing speech 151/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0406a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0406a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0406a.pdf
# Error downloading PDF ko0406a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0406a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130629a.htm, skipping.
# Processing speech 153/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0412c.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0412c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0412c.pdf
# Error downloading PDF ko0412c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0412c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230905a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170510b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130319b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130722a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0505c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170622a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210215a.htm, skipping.
# Processing speech 161/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0402a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0402a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0402a.pdf
# Error downloading PDF ko0402a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0402a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110111a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110506a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200206a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201104a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180921a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160112a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221114a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201203a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141225a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170810a.htm, skipping.
# Processing speech 172/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0801a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0801a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0801a.pdf
# Error downloading PDF ko0801a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0801a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120111a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131202a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201224a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240910a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181116a.htm, skipping.
# Processing speech 178/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0304d.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0304d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0304d.pdf
# Error downloading PDF ko0304d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0304d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131127a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190607a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0010a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120604a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141112b.htm, skipping.
# Processing speech 184/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0709a.pdf
# Error downloading PDF ko0709a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0709a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130927a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0410a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190117a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111031a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0312c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160318a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191021a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0306b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0606b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121012a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111206a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140824a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0705a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131018a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0210a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0407a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151207a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110930a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161009a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120910a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160623a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0508a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0311a.htm, skipping.
# Processing speech 208/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0906a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0906a.pdf
# Error downloading PDF ko0906a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0906a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko200601a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190522a.htm, skipping.
# Processing speech 211/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0812e.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0812e.pdf
# Error downloading PDF ko0812e.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0812e.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170329a.htm, skipping.
# Processing speech 213/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0807b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0807b.pdf
# Error downloading PDF ko0807b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0807b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110525a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140319b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181025a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0101a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211021a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221214a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190925a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120612a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160203a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131007a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161205a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0304c.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160309a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140206a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220331a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171129a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120924a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190710a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190904a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0110a.htm, skipping.
# Processing speech 235/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0806d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0806d.pdf
# Error downloading PDF ko0806d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0806d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240305a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170606a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0711b.htm, skipping.
# Processing speech 239/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0912d.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0912d.pdf
# Error downloading PDF ko0912d.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0912d.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170301a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120725a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0512a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230228a.htm, skipping.
# Processing speech 244/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0809b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0809b.pdf
# Error downloading PDF ko0809b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0809b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150211a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110411a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170216a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180530a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko241011a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150515a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150903a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180416a.htm, skipping.
# Processing speech 253/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0009b.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0009b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0009b.pdf
# Error downloading PDF ko0009b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0009b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190924a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210326a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0612b.htm, skipping.
# Processing speech 257/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0712b.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0712b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0712b.pdf
# Error downloading PDF ko0712b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0712b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180803a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0502a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110930b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170404a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221222a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110621a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210519a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170120a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160322a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160226a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0606c.htm, skipping.
# Processing speech 269/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0402b.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0402b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0402b.pdf
# Error downloading PDF ko0402b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0402b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210526a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141204a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0103a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210203a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170925a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120821a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201124b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0207b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0602a.htm, skipping.
# Processing speech 279/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0910b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0910b.pdf
# Error downloading PDF ko0910b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0910b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150727a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130529a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220601a.htm, skipping.
# Processing speech 283/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0912a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0912a.pdf
# Error downloading PDF ko0912a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0912a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160908a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171114a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190902a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0503b.htm, skipping.
# Processing speech 288/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0302a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0302a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0302a.pdf
# Error downloading PDF ko0302a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0302a.pdf
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0307a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181105a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130528a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211006a.htm, skipping.
# Processing speech 293/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0811a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0811a.pdf
# Error downloading PDF ko0811a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0811a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161021b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230301a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160225a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140916a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221026a.htm, skipping.
# Processing speech 299/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0908a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0908a.pdf
# Error downloading PDF ko0908a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0908a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171226a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211129a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140724b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140724a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170413a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180510a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0709b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2004/ko0407c.htm, skipping.
# Processing speech 308/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0906b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0906b.pdf
# Error downloading PDF ko0906b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0906b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140324a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0111a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131204a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150610b.htm, skipping.
# Processing speech 313/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0811b.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0811b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0811b.pdf
# Error downloading PDF ko0811b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0811b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191225a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110325b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201112a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131122a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140319a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191205a.htm, skipping.
# Processing speech 320/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0204a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0204a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0204a.pdf
# Error downloading PDF ko0204a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0204a.pdf
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9907d.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140929a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221127a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121011a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150228a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211223a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141125b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160523a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201106a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151125a.htm, skipping.
# Processing speech 331/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0811f.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0811f.pdf
# Error downloading PDF ko0811f.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0811f.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150524a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160804a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200214a.htm, skipping.
# Processing speech 335/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0905c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0905c.pdf
# Error downloading PDF ko0905c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0905c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140423a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111202a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9904a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0703a.pdf, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140526a.htm, skipping.
# Processing speech 341/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0909d.htm
# ...
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151130a.htm, skipping.
# Processing speech 597/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0304a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0304a.pdf
# Error downloading PDF ko0304a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0304a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220728a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190612a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140319d.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131105a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131207a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190315a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160330a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0202b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150311a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180601a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121203a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190627a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210524a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181212a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110308a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110408a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230906a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141120a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130131a.htm, skipping.
# Processing speech 617/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0812a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0812a.pdf
# Error downloading PDF ko0812a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0812a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191107a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150909a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201030a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko191212a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170601a.htm, skipping.
# Processing speech 623/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0906e.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0906e.pdf
# Error downloading PDF ko0906e.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0906e.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160414a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170307a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220525a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180904a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161108a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220413c.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0203a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0506a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120530a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240403a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0804a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110305a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko181119a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0309b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131028a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110224a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0801d.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0201a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220307a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130105a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110906a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210727a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0603a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210721a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0606a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111226a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2007/ko0701a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230828a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9905a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120210a.htm, skipping.
# Processing speech 654/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0807a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0807a.pdf
# Error downloading PDF ko0807a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0807a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140528a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150827a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240306a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_1999/ko9912a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110725a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0310c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140221a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200923a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210602a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221208a.htm, skipping.
# Processing speech 665/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0112a.htm
# Using first available PDF link for speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2001/ko0112a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0112a.pdf
# Error downloading PDF ko0112a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0112a.pdf
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0205a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko231207a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0510a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160620a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110805a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko111130a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180704a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko221124a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko171130a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240502a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151224a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240924a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2024/ko240208a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0011a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120517a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0305a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130825a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180301a.htm, skipping.
# Processing speech 684/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0808b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0808b.pdf
# Error downloading PDF ko0808b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0808b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141125a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210901a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160912a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110218a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2018/ko180629a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko141009a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151106a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko151202a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0007a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko121129a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140608a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120912a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko160414b.htm, skipping.
# Processing speech 698/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2008/ko0809a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0809a.pdf
# Error downloading PDF ko0809a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0809a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130116a.htm, skipping.
# Processing speech 700/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0901b.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0901b.pdf
# Error downloading PDF ko0901b.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0901b.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2019/ko190308a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2017/ko170214a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2005/ko0505b.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2002/ko0207a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2012/ko120208a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2003/ko0310b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko201007a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131013a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko211202a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0609a.pdf, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2011/ko110421a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230627a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0012a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko131009a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2006/ko0604c.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2014/ko140801a.htm, skipping.
# Processing speech 717/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0903c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0903c.pdf
# Error downloading PDF ko0903c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0903c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2023/ko230328a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2021/ko210316a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0009c.htm, skipping.
# Processing speech 721/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0904c.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0904c.pdf
# Error downloading PDF ko0904c.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0904c.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130531a.htm, skipping.
# Already processed speech at https://www2.boj.or.jp/archive/en/announcements/press/koen_2000/ko0007b.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2015/ko150304a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2020/ko200626a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2013/ko130418a.htm, skipping.
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2016/ko161226a.htm, skipping.
# Processing speech 728/729: https://www2.boj.or.jp/archive/en/announcements/press/koen_2009/ko0903a.htm
# Found PDF URL: https://www2.boj.or.jp/data/ko0903a.pdf
# Error downloading PDF ko0903a.pdf: 403 Client Error: Forbidden for url: https://www2.boj.or.jp/data/ko0903a.pdf
# Already processed speech at https://www.boj.or.jp/en/about/press/koen_2022/ko220905a.htm, skipping.
# CSV file updated at /Users/kylenabors/Documents/Database/Training Data/Japan/japan_speeches/japan_speeches.csv
