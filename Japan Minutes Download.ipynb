# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from PyPDF2 import PdfReader
import pandas as pd
import pdfkit  # For converting .htm to .pdf

# Directories
pdf_dir = "/Users/kylenabors/Documents/Database/Training Data/boj/boj_minutes/PDFs"
csv_path = (
    "/Users/kylenabors/Documents/Database/Training Data/boj/boj_minutes/boj_minutes.csv"
)

# Create PDF directory if it doesn't exist
if not os.path.exists(pdf_dir):
    os.makedirs(pdf_dir)

# Base URLs
base_url = "https://www.boj.or.jp"
main_url = f"{base_url}/en/mopo/mpmsche_minu/minu_all/index.htm"

# Get list of years
response = requests.get(main_url)
soup = BeautifulSoup(response.content, "html.parser")
year_links = soup.find_all(
    "a", href=re.compile(r"/en/mopo/mpmsche_minu/minu_\d{4}/index\.htm")
)

years = []
for link in year_links:
    year_url = base_url + link["href"]
    years.append(year_url)

# Get PDF/HTM links for each year
pdf_links = []
htm_links = []
for year_url in years:
    response = requests.get(year_url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract the year from the URL
    year_match = re.search(r"minu_(\d{4})", year_url)
    if year_match:
        year = int(year_match.group(1))

    for link in soup.find_all("a", href=True):
        href = link["href"]
        if re.search(r"g\d{6}\.pdf", href):
            pdf_links.append(base_url + href)
        elif re.search(r"g\d{6}\.htm", href) and year > 2006:
            href = href.replace(".htm", ".pdf")
            pdf_links.append(base_url + href)
        elif re.search(r"g\d{6}\.htm", href) and year <= 2006:
            htm_links.append(base_url + href)

for url in htm_links:
    filename = url.split("/")[-1]
    filename = filename.replace(".htm", ".pdf")
    pdf_path = os.path.join(pdf_dir, filename)

    # Skip already downloaded files
    if os.path.exists(pdf_path):
        print(f"Skipping {filename} (already downloaded).")
        continue
    print(url)
    pdfkit.from_url(url, pdf_path)
    print(f"Downloaded {filename} as PDF.")

# Download and process files
for url in pdf_links:
    filename = url.split("/")[-1]
    pdf_path = os.path.join(pdf_dir, filename)

    # Skip already downloaded files
    if os.path.exists(pdf_path):
        print(f"Skipping {filename} (already downloaded).")
        continue

    response = requests.get(url)
    if url.endswith(".htm"):
        html_path = os.path.join(pdf_dir, filename)
        with open(html_path, "wb") as f:
            f.write(response.content)
        print(f"Downloaded {filename} as HTML.")

        # Convert HTML to PDF
        try:
            pdfkit.from_url(htm_links, pdf_path)
            os.remove(html_path)  # Remove the HTML file after conversion
            print(f"Converted {filename} to PDF.")
        except Exception as e:
            print(f"Error converting {filename} to PDF: {e}")
    else:
        with open(pdf_path, "wb") as f:
            f.write(response.content)
        print(f"Downloaded {filename} as PDF.")

# Read existing CSV data (if any)
if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    if "date" in existing_df.columns:
        existing_dates = set(pd.to_datetime(existing_df["date"]).dt.date)
    else:
        existing_dates = set()
else:
    existing_df = pd.DataFrame()
    existing_dates = set()

# Extract text from PDFs and extract date from filename
pdf_texts = []
for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        date_match = re.match(r"g(\d{6})\.pdf", pdf_file)
        if date_match:
            date_str = date_match.group(1)
            date = pd.to_datetime(date_str, format="%y%m%d").date()
        else:
            date = None

        if date in existing_dates:
            print(f"Data for date {date} already in CSV, skipping.")
            continue

        try:
            with open(pdf_path, "rb") as f:
                reader = PdfReader(f)
                text = "".join([page.extract_text() for page in reader.pages])
                pdf_texts.append({"date": date, "text": text})
        except Exception as e:
            print(f"Error reading {pdf_file}: {e}")

# Combine new data with existing data and save to CSV
new_df = pd.DataFrame(pdf_texts)
if not existing_df.empty:
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)
else:
    combined_df = new_df

combined_df.to_csv(csv_path, index=False)
print(f"CSV file updated at {csv_path}")
# Out:
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060519.htm
# Downloaded g060519.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060428.htm
# Downloaded g060428.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060411.htm
# Downloaded g060411.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060309.htm
# Downloaded g060309.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060209.htm
# Downloaded g060209.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2006/g060120.htm
# Downloaded g060120.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g051216.htm
# Downloaded g051216.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g051118.htm
# Downloaded g051118.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g051031.htm
# Downloaded g051031.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g051012.htm
# Downloaded g051012.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050908.htm
# Downloaded g050908.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050809.htm
# Downloaded g050809.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050727.htm
# Downloaded g050727.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050713.htm
# Downloaded g050713.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050615.htm
# Downloaded g050615.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050520.htm
# Downloaded g050520.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050428.htm
# Downloaded g050428.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050406.htm
# Downloaded g050406.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050316.htm
# Downloaded g050316.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050217.htm
# Downloaded g050217.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2005/g050119.htm
# Downloaded g050119.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g041217.htm
# Downloaded g041217.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g041118.htm
# Downloaded g041118.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g041029.htm
# Downloaded g041029.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g041013.htm
# Downloaded g041013.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040909.htm
# Downloaded g040909.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040810.htm
# Downloaded g040810.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040713.htm
# Downloaded g040713.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040625.htm
# Downloaded g040625.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040615.htm
# Downloaded g040615.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040520.htm
# Downloaded g040520.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040428.htm
# Downloaded g040428.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040409.htm
# Downloaded g040409.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040316.htm
# Downloaded g040316.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040226.htm
# Downloaded g040226.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040205.htm
# Downloaded g040205.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2004/g040120.htm
# Downloaded g040120.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g031216.htm
# Downloaded g031216.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g031121.htm
# Downloaded g031121.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g031031.htm
# Downloaded g031031.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g031010.htm
# Downloaded g031010.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030912.htm
# Downloaded g030912.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030808.htm
# Downloaded g030808.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030715.htm
# Downloaded g030715.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030625.htm
# Downloaded g030625.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030611.htm
# Downloaded g030611.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030520.htm
# Downloaded g030520.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030430.htm
# Downloaded g030430.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030408.htm
# Downloaded g030408.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030325.htm
# Downloaded g030325.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030305.htm
# Downloaded g030305.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030214.htm
# Downloaded g030214.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2003/g030122.htm
# Downloaded g030122.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g021217.htm
# Downloaded g021217.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g021119.htm
# Downloaded g021119.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g021030.htm
# Downloaded g021030.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g021011.htm
# Downloaded g021011.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020918.htm
# Downloaded g020918.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020809.htm
# Downloaded g020809.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020716.htm
# Downloaded g020716.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020626.htm
# Downloaded g020626.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020612.htm
# Downloaded g020612.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020521.htm
# Downloaded g020521.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020430.htm
# Downloaded g020430.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020411.htm
# Downloaded g020411.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020320.htm
# Downloaded g020320.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020228.htm
# Downloaded g020228.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020208.htm
# Downloaded g020208.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2002/g020116.htm
# Downloaded g020116.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g011219.htm
# Downloaded g011219.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g011129.htm
# Downloaded g011129.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g011116.htm
# Downloaded g011116.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g011029.htm
# Downloaded g011029.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g011012.htm
# Downloaded g011012.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010918.htm
# Downloaded g010918.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010814.htm
# Downloaded g010814.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010713.htm
# Downloaded g010713.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010628.htm
# Downloaded g010628.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010615.htm
# Downloaded g010615.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010518.htm
# Downloaded g010518.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010425.htm
# Downloaded g010425.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010413.htm
# Downloaded g010413.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010319.htm
# Downloaded g010319.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010228.htm
# Downloaded g010228.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010209.htm
# Downloaded g010209.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2001/g010119.htm
# Downloaded g010119.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g001215.htm
# Downloaded g001215.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g001130.htm
# Downloaded g001130.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g001117.htm
# Downloaded g001117.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g001030.htm
# Downloaded g001030.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g001013.htm
# Downloaded g001013.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000914.htm
# Downloaded g000914.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000811.htm
# Downloaded g000811.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000717.htm
# Downloaded g000717.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000628.htm
# Downloaded g000628.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000612.htm
# Downloaded g000612.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000517.htm
# Downloaded g000517.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000427.htm
# Downloaded g000427.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000410.htm
# Downloaded g000410.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000324.htm
# Downloaded g000324.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000308.htm
# Downloaded g000308.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000224.htm
# Downloaded g000224.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000210.htm
# Downloaded g000210.pdf as PDF.
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2000/g000117.htm
# Downloaded g000117.pdf as PDF.
# Skipping g991217.pdf (already downloaded).
# Skipping g991126.pdf (already downloaded).
# Skipping g991112.pdf (already downloaded).
# Skipping g991027.pdf (already downloaded).
# Skipping g991013.pdf (already downloaded).
# Skipping g990921.pdf (already downloaded).
# Skipping g990909.pdf (already downloaded).
# Skipping g990813.pdf (already downloaded).
# Skipping g990716.pdf (already downloaded).
# Skipping g990628.pdf (already downloaded).
# Skipping g990614.pdf (already downloaded).
# Skipping g990518.pdf (already downloaded).
# Skipping g990422.pdf (already downloaded).
# Skipping g990409.pdf (already downloaded).
# Skipping g990325.pdf (already downloaded).
# Skipping g990312.pdf (already downloaded).
# Skipping g990225.pdf (already downloaded).
# Skipping g990212.pdf (already downloaded).
# Skipping g990119.pdf (already downloaded).
# Skipping g981215.pdf (already downloaded).
# Skipping g981127.pdf (already downloaded).
# Skipping g981113.pdf (already downloaded).
# Skipping g981028.pdf (already downloaded).
# Skipping g981013.pdf (already downloaded).
# Skipping g980924.pdf (already downloaded).
# Skipping g980909.pdf (already downloaded).
# Skipping g980811.pdf (already downloaded).
# Skipping g980728.pdf (already downloaded).
# Skipping g980716.pdf (already downloaded).
# Skipping g980625.pdf (already downloaded).
# Skipping g980612.pdf (already downloaded).
# Skipping g980519.pdf (already downloaded).
# Skipping g980424.pdf (already downloaded).
# Skipping g980409.pdf (already downloaded).
# Skipping g980326.pdf (already downloaded).
# Skipping g980313.pdf (already downloaded).
# Skipping g980226.pdf (already downloaded).
# Skipping g980213.pdf (already downloaded).
# Skipping g980116.pdf (already downloaded).
# Skipping g240731.pdf (already downloaded).
# Skipping g240614.pdf (already downloaded).
# Skipping g240426.pdf (already downloaded).
# Skipping g240319.pdf (already downloaded).
# Skipping g240123.pdf (already downloaded).
# Skipping g240731.pdf (already downloaded).
# Skipping g240614.pdf (already downloaded).
# Skipping g240426.pdf (already downloaded).
# Skipping g240319.pdf (already downloaded).
# Skipping g240123.pdf (already downloaded).
# Skipping g231219.pdf (already downloaded).
# Skipping g231031.pdf (already downloaded).
# Skipping g230922.pdf (already downloaded).
# Skipping g230728.pdf (already downloaded).
# Skipping g230616.pdf (already downloaded).
# Skipping g230428.pdf (already downloaded).
# Skipping g230310.pdf (already downloaded).
# Skipping g230118.pdf (already downloaded).
# Skipping g221220.pdf (already downloaded).
# Skipping g221028.pdf (already downloaded).
# Skipping g220922.pdf (already downloaded).
# Skipping g220721.pdf (already downloaded).
# Skipping g220617.pdf (already downloaded).
# Skipping g220428.pdf (already downloaded).
# Skipping g220318.pdf (already downloaded).
# Skipping g220118.pdf (already downloaded).
# Skipping g211217.pdf (already downloaded).
# Skipping g211028.pdf (already downloaded).
# Skipping g210922.pdf (already downloaded).
# Skipping g210716.pdf (already downloaded).
# Skipping g210618.pdf (already downloaded).
# Skipping g210427.pdf (already downloaded).
# Skipping g210319.pdf (already downloaded).
# Skipping g210121.pdf (already downloaded).
# Skipping g201218.pdf (already downloaded).
# Skipping g201029.pdf (already downloaded).
# Skipping g200917.pdf (already downloaded).
# Skipping g200715.pdf (already downloaded).
# Skipping g200616.pdf (already downloaded).
# Skipping g200522.pdf (already downloaded).
# Skipping g200427.pdf (already downloaded).
# Skipping g200316.pdf (already downloaded).
# Skipping g200121.pdf (already downloaded).
# Skipping g191219.pdf (already downloaded).
# Skipping g191031.pdf (already downloaded).
# Skipping g190919.pdf (already downloaded).
# Skipping g190730.pdf (already downloaded).
# Skipping g190620.pdf (already downloaded).
# Skipping g190425.pdf (already downloaded).
# Skipping g190315.pdf (already downloaded).
# Skipping g190123.pdf (already downloaded).
# Skipping g181220.pdf (already downloaded).
# Skipping g181031.pdf (already downloaded).
# Skipping g180919.pdf (already downloaded).
# Skipping g180731.pdf (already downloaded).
# Skipping g180615.pdf (already downloaded).
# Skipping g180427.pdf (already downloaded).
# Skipping g180309.pdf (already downloaded).
# Skipping g180123.pdf (already downloaded).
# Skipping g171221.pdf (already downloaded).
# Skipping g171031.pdf (already downloaded).
# Skipping g170921.pdf (already downloaded).
# Skipping g170720.pdf (already downloaded).
# Skipping g170616.pdf (already downloaded).
# Skipping g170427.pdf (already downloaded).
# Skipping g170316.pdf (already downloaded).
# Skipping g170131.pdf (already downloaded).
# Skipping g161220.pdf (already downloaded).
# Skipping g161101.pdf (already downloaded).
# Skipping g160921.pdf (already downloaded).
# Skipping g160729.pdf (already downloaded).
# Skipping g160616.pdf (already downloaded).
# Skipping g160428.pdf (already downloaded).
# Skipping g160315.pdf (already downloaded).
# Skipping g160129.pdf (already downloaded).
# Skipping g151218.pdf (already downloaded).
# Skipping g151119.pdf (already downloaded).
# Skipping g151030.pdf (already downloaded).
# Skipping g151007.pdf (already downloaded).
# Skipping g150915.pdf (already downloaded).
# Skipping g150807.pdf (already downloaded).
# Skipping g150715.pdf (already downloaded).
# Skipping g150619.pdf (already downloaded).
# Skipping g150522.pdf (already downloaded).
# Skipping g150430.pdf (already downloaded).
# Skipping g150408.pdf (already downloaded).
# Skipping g150317.pdf (already downloaded).
# Skipping g150218.pdf (already downloaded).
# Skipping g150121.pdf (already downloaded).
# Skipping g141219.pdf (already downloaded).
# Skipping g141119.pdf (already downloaded).
# Skipping g141031.pdf (already downloaded).
# Skipping g141007.pdf (already downloaded).
# Skipping g140904.pdf (already downloaded).
# Skipping g140808.pdf (already downloaded).
# Skipping g140715.pdf (already downloaded).
# Skipping g140613.pdf (already downloaded).
# Skipping g140521.pdf (already downloaded).
# Skipping g140430.pdf (already downloaded).
# Skipping g140408.pdf (already downloaded).
# Skipping g140311.pdf (already downloaded).
# Skipping g140218.pdf (already downloaded).
# Skipping g140122.pdf (already downloaded).
# Skipping g131220.pdf (already downloaded).
# Skipping g131121.pdf (already downloaded).
# Skipping g131031.pdf (already downloaded).
# Skipping g131004.pdf (already downloaded).
# Skipping g130905.pdf (already downloaded).
# Skipping g130808.pdf (already downloaded).
# Skipping g130711.pdf (already downloaded).
# Skipping g130611.pdf (already downloaded).
# Skipping g130522.pdf (already downloaded).
# Skipping g130426.pdf (already downloaded).
# Skipping g130404.pdf (already downloaded).
# Skipping g130307.pdf (already downloaded).
# Skipping g130214.pdf (already downloaded).
# Skipping g130122.pdf (already downloaded).
# Skipping g121220.pdf (already downloaded).
# Skipping g121120.pdf (already downloaded).
# Skipping g121030.pdf (already downloaded).
# Skipping g121005.pdf (already downloaded).
# Skipping g120919.pdf (already downloaded).
# Skipping g120809.pdf (already downloaded).
# Skipping g120712.pdf (already downloaded).
# Skipping g120615.pdf (already downloaded).
# Skipping g120523.pdf (already downloaded).
# Skipping g120427.pdf (already downloaded).
# Skipping g120410.pdf (already downloaded).
# Skipping g120313.pdf (already downloaded).
# Skipping g120214.pdf (already downloaded).
# Skipping g120124.pdf (already downloaded).
# Skipping g111221.pdf (already downloaded).
# Skipping g111130.pdf (already downloaded).
# Skipping g111116.pdf (already downloaded).
# Skipping g111027.pdf (already downloaded).
# Skipping g111007.pdf (already downloaded).
# Skipping g110907.pdf (already downloaded).
# Skipping g110804.pdf (already downloaded).
# Skipping g110712.pdf (already downloaded).
# Skipping g110614.pdf (already downloaded).
# Skipping g110520.pdf (already downloaded).
# Skipping g110428.pdf (already downloaded).
# Skipping g110407.pdf (already downloaded).
# Skipping g110314.pdf (already downloaded).
# Skipping g110215.pdf (already downloaded).
# Skipping g110125.pdf (already downloaded).
# Skipping g101221.pdf (already downloaded).
# Skipping g101105.pdf (already downloaded).
# Skipping g101028.pdf (already downloaded).
# Skipping g101005.pdf (already downloaded).
# Skipping g100907.pdf (already downloaded).
# Skipping g100830.pdf (already downloaded).
# Skipping g100810.pdf (already downloaded).
# Skipping g100715.pdf (already downloaded).
# Skipping g100615.pdf (already downloaded).
# Skipping g100521.pdf (already downloaded).
# Skipping g100510.pdf (already downloaded).
# Skipping g100430.pdf (already downloaded).
# Skipping g100407.pdf (already downloaded).
# Skipping g100317.pdf (already downloaded).
# Skipping g100218.pdf (already downloaded).
# Skipping g100126.pdf (already downloaded).
# Skipping g091218.pdf (already downloaded).
# Skipping g091201.pdf (already downloaded).
# Skipping g091120.pdf (already downloaded).
# Skipping g091030.pdf (already downloaded).
# Skipping g091014.pdf (already downloaded).
# Skipping g090917.pdf (already downloaded).
# Skipping g090811.pdf (already downloaded).
# Skipping g090715.pdf (already downloaded).
# Skipping g090616.pdf (already downloaded).
# Skipping g090522.pdf (already downloaded).
# Skipping g090430.pdf (already downloaded).
# Skipping g090407.pdf (already downloaded).
# Skipping g090318.pdf (already downloaded).
# Skipping g090219.pdf (already downloaded).
# Skipping g090122.pdf (already downloaded).
# Skipping g081219.pdf (already downloaded).
# Skipping g081202.pdf (already downloaded).
# Skipping g081121.pdf (already downloaded).
# Skipping g081031.pdf (already downloaded).
# Skipping g081014.pdf (already downloaded).
# Skipping g081007.pdf (already downloaded).
# Skipping g080929.pdf (already downloaded).
# Skipping g080918.pdf (already downloaded).
# Skipping g080917.pdf (already downloaded).
# Skipping g080819.pdf (already downloaded).
# Skipping g080715.pdf (already downloaded).
# Skipping g080613.pdf (already downloaded).
# Skipping g080520.pdf (already downloaded).
# Skipping g080430.pdf (already downloaded).
# Skipping g080409.pdf (already downloaded).
# Skipping g080307.pdf (already downloaded).
# Skipping g080215.pdf (already downloaded).
# Skipping g080122.pdf (already downloaded).
# Skipping g071220.pdf (already downloaded).
# Skipping g071113.pdf (already downloaded).
# Skipping g071031.pdf (already downloaded).
# Skipping g071011.pdf (already downloaded).
# Skipping g070919.pdf (already downloaded).
# Skipping g070823.pdf (already downloaded).
# Skipping g070712.pdf (already downloaded).
# Skipping g070615.pdf (already downloaded).
# Skipping g070517.pdf (already downloaded).
# Skipping g070427.pdf (already downloaded).
# Skipping g070410.pdf (already downloaded).
# Skipping g070320.pdf (already downloaded).
# Skipping g070221.pdf (already downloaded).
# Skipping g070118.pdf (already downloaded).
# Skipping g061219.pdf (already downloaded).
# Skipping g061116.pdf (already downloaded).
# Skipping g061031.pdf (already downloaded).
# Skipping g061013.pdf (already downloaded).
# Skipping g060908.pdf (already downloaded).
# Skipping g060811.pdf (already downloaded).
# Skipping g060714.pdf (already downloaded).
# Skipping g060615.pdf (already downloaded).
# Data for date 2017-07-20 already in CSV, skipping.
# Data for date 2015-06-19 already in CSV, skipping.
# Data for date 2011-02-15 already in CSV, skipping.
# Data for date 2020-01-21 already in CSV, skipping.
# Data for date 2014-02-18 already in CSV, skipping.
# Data for date 2011-04-07 already in CSV, skipping.
# Data for date 2020-10-29 already in CSV, skipping.
# Error reading g980326.pdf: EOF marker not found
# Error reading g991217.pdf: EOF marker not found
# Data for date 2008-11-21 already in CSV, skipping.
# Data for date 2010-06-15 already in CSV, skipping.
# Data for date 2008-06-13 already in CSV, skipping.
# Error reading g990518.pdf: EOF marker not found
# Data for date 2009-06-16 already in CSV, skipping.
# Data for date 2012-12-20 already in CSV, skipping.
# Data for date 2013-10-31 already in CSV, skipping.
# Data for date 2013-03-07 already in CSV, skipping.
# Data for date 2015-04-30 already in CSV, skipping.
# Data for date 2020-09-17 already in CSV, skipping.
# Data for date 2010-08-30 already in CSV, skipping.
# Data for date 2007-10-11 already in CSV, skipping.
# Data for date 2021-03-19 already in CSV, skipping.
# Data for date 2017-01-31 already in CSV, skipping.
# Data for date 2012-07-12 already in CSV, skipping.
# Data for date 2008-02-15 already in CSV, skipping.
# Error reading g981013.pdf: EOF marker not found
# Data for date 2007-01-18 already in CSV, skipping.
# Data for date 2014-04-08 already in CSV, skipping.
# Data for date 2012-03-13 already in CSV, skipping.
# Data for date 2009-04-07 already in CSV, skipping.
# Data for date 2014-04-30 already in CSV, skipping.
# Error reading g991013.pdf: EOF marker not found
# Error reading g990325.pdf: EOF marker not found
# Data for date 2012-09-19 already in CSV, skipping.
# Data for date 2011-04-28 already in CSV, skipping.
# Error reading g981215.pdf: EOF marker not found
# Data for date 2011-11-30 already in CSV, skipping.
# Data for date 2018-06-15 already in CSV, skipping.
# Data for date 2012-10-30 already in CSV, skipping.
# Data for date 2015-04-08 already in CSV, skipping.
# Data for date 2020-05-22 already in CSV, skipping.
# Error reading g980519.pdf: EOF marker not found
# Data for date 2015-08-07 already in CSV, skipping.
# Data for date 2013-07-11 already in CSV, skipping.
# Data for date 2009-11-20 already in CSV, skipping.
# Data for date 2021-12-17 already in CSV, skipping.
# Data for date 2021-01-21 already in CSV, skipping.
# Data for date 2011-06-14 already in CSV, skipping.
# Data for date 2010-04-07 already in CSV, skipping.
# Data for date 2015-02-18 already in CSV, skipping.
# Error reading g981028.pdf: EOF marker not found
# Error reading g990119.pdf: EOF marker not found
# Data for date 2006-10-13 already in CSV, skipping.
# Data for date 2021-10-28 already in CSV, skipping.
# Data for date 2007-03-20 already in CSV, skipping.
# Data for date 2013-12-20 already in CSV, skipping.
# Data for date 2008-08-19 already in CSV, skipping.
# Error reading g981113.pdf: EOF marker not found
# Data for date 2012-08-09 already in CSV, skipping.
# Data for date 2011-07-12 already in CSV, skipping.
# Data for date 2009-12-18 already in CSV, skipping.
# Data for date 2012-04-10 already in CSV, skipping.
# Data for date 2015-09-15 already in CSV, skipping.
# Data for date 2012-11-20 already in CSV, skipping.
# Data for date 2014-05-21 already in CSV, skipping.
# Data for date 2014-09-04 already in CSV, skipping.
# Data for date 2022-07-21 already in CSV, skipping.
# Data for date 2009-07-15 already in CSV, skipping.
# Data for date 2020-04-27 already in CSV, skipping.
# Data for date 2015-01-21 already in CSV, skipping.
# Data for date 2022-03-18 already in CSV, skipping.
# Data for date 2018-12-20 already in CSV, skipping.
# Data for date 2019-12-19 already in CSV, skipping.
# Data for date 2016-11-01 already in CSV, skipping.
# Error reading g980226.pdf: EOF marker not found
# Data for date 2022-01-18 already in CSV, skipping.
# Data for date 2019-10-31 already in CSV, skipping.
# Error reading g980811.pdf: EOF marker not found
# Data for date 2011-12-21 already in CSV, skipping.
# Error reading g980409.pdf: EOF marker not found
# Data for date 2019-09-19 already in CSV, skipping.
# Data for date 2011-03-14 already in CSV, skipping.
# Data for date 2012-02-14 already in CSV, skipping.
# Data for date 2010-07-15 already in CSV, skipping.
# Data for date 2009-10-30 already in CSV, skipping.
# Data for date 2014-10-07 already in CSV, skipping.
# Data for date 2007-11-13 already in CSV, skipping.
# Data for date 2006-11-16 already in CSV, skipping.
# Data for date 2008-03-07 already in CSV, skipping.
# Data for date 2008-10-31 already in CSV, skipping.
# Data for date 2018-10-31 already in CSV, skipping.
# Data for date 2007-02-21 already in CSV, skipping.
# Data for date 2013-06-11 already in CSV, skipping.
# Data for date 2023-01-18 already in CSV, skipping.
# Data for date 2007-04-27 already in CSV, skipping.
# Data for date 2008-09-18 already in CSV, skipping.
# Data for date 2017-04-27 already in CSV, skipping.
# Data for date 2010-12-21 already in CSV, skipping.
# Data for date 2015-05-22 already in CSV, skipping.
# Error reading g980424.pdf: EOF marker not found
# Data for date 2013-02-14 already in CSV, skipping.
# Data for date 2011-10-27 already in CSV, skipping.
# Error reading g990409.pdf: EOF marker not found
# Data for date 2018-09-19 already in CSV, skipping.
# Data for date 2022-10-28 already in CSV, skipping.
# Data for date 2015-10-07 already in CSV, skipping.
# Data for date 2014-01-22 already in CSV, skipping.
# Data for date 2012-06-15 already in CSV, skipping.
# Data for date 2013-04-04 already in CSV, skipping.
# Data for date 2010-05-10 already in CSV, skipping.
# Data for date 2019-03-15 already in CSV, skipping.
# Error reading g990225.pdf: EOF marker not found
# Data for date 2021-06-18 already in CSV, skipping.
# Data for date 2010-03-17 already in CSV, skipping.
# Data for date 2013-11-21 already in CSV, skipping.
# Error reading g990813.pdf: EOF marker not found
# Error reading g980625.pdf: EOF marker not found
# Data for date 2006-08-11 already in CSV, skipping.
# Error reading g990422.pdf: EOF marker not found
# Data for date 2008-07-15 already in CSV, skipping.
# Data for date 2021-04-27 already in CSV, skipping.
# Data for date 2013-08-08 already in CSV, skipping.
# Data for date 2008-12-19 already in CSV, skipping.
# Error reading g991112.pdf: EOF marker not found
# Data for date 2024-06-14 already in CSV, skipping.
# Data for date 2015-03-17 already in CSV, skipping.
# Data for date 2008-01-22 already in CSV, skipping.
# Data for date 2008-09-17 already in CSV, skipping.
# Data for date 2023-09-22 already in CSV, skipping.
# Data for date 2017-06-16 already in CSV, skipping.
# Data for date 2010-10-05 already in CSV, skipping.
# Data for date 2018-07-31 already in CSV, skipping.
# Data for date 2009-05-22 already in CSV, skipping.
# Data for date 2018-01-23 already in CSV, skipping.
# Data for date 2009-03-18 already in CSV, skipping.
# Data for date 2014-10-31 already in CSV, skipping.
# Data for date 2024-04-26 already in CSV, skipping.
# Data for date 2010-05-21 already in CSV, skipping.
# Error reading g981127.pdf: EOF marker not found
# Data for date 2018-03-09 already in CSV, skipping.
# Error reading g980213.pdf: EOF marker not found
# Data for date 2014-12-19 already in CSV, skipping.
# Data for date 2014-03-11 already in CSV, skipping.
# Data for date 2007-06-15 already in CSV, skipping.
# Data for date 2014-07-15 already in CSV, skipping.
# Data for date 2010-01-26 already in CSV, skipping.
# Data for date 2008-09-29 already in CSV, skipping.
# Data for date 2008-12-02 already in CSV, skipping.
# Data for date 2012-04-27 already in CSV, skipping.
# Data for date 2010-09-07 already in CSV, skipping.
# Data for date 2008-10-14 already in CSV, skipping.
# Data for date 2013-04-26 already in CSV, skipping.
# Data for date 2023-10-31 already in CSV, skipping.
# Data for date 2006-06-15 already in CSV, skipping.
# Data for date 2015-07-15 already in CSV, skipping.
# Data for date 2011-10-07 already in CSV, skipping.
# Error reading g980612.pdf: EOF marker not found
# Data for date 2008-05-20 already in CSV, skipping.
# Data for date 2007-08-23 already in CSV, skipping.
# Data for date 2020-06-16 already in CSV, skipping.
# Error reading g990212.pdf: EOF marker not found
# Data for date 2009-10-14 already in CSV, skipping.
# Data for date 2015-12-18 already in CSV, skipping.
# Data for date 2011-09-07 already in CSV, skipping.
# Data for date 2009-01-22 already in CSV, skipping.
# Data for date 2008-10-07 already in CSV, skipping.
# Data for date 2023-03-10 already in CSV, skipping.
# Data for date 2015-10-30 already in CSV, skipping.
# Data for date 2011-05-20 already in CSV, skipping.
# Error reading g991126.pdf: EOF marker not found
# Data for date 2016-06-16 already in CSV, skipping.
# Data for date 2023-07-28 already in CSV, skipping.
# Data for date 2022-09-22 already in CSV, skipping.
# Data for date 2016-04-28 already in CSV, skipping.
# Data for date 2009-09-17 already in CSV, skipping.
# Data for date 2019-07-30 already in CSV, skipping.
# Error reading g990628.pdf: EOF marker not found
# Error reading g990614.pdf: EOF marker not found
# Data for date 2011-01-25 already in CSV, skipping.
# Data for date 2010-10-28 already in CSV, skipping.
# Data for date 2007-04-10 already in CSV, skipping.
# Data for date 2023-12-19 already in CSV, skipping.
# Data for date 2009-12-01 already in CSV, skipping.
# Data for date 2019-01-23 already in CSV, skipping.
# Data for date 2022-12-20 already in CSV, skipping.
# Data for date 2009-08-11 already in CSV, skipping.
# Error reading g990909.pdf: EOF marker not found
# Error reading g990921.pdf: EOF marker not found
# Data for date 2022-06-17 already in CSV, skipping.
# Error reading g980924.pdf: EOF marker not found
# Data for date 2007-05-17 already in CSV, skipping.
# Data for date 2011-11-16 already in CSV, skipping.
# Data for date 2016-12-20 already in CSV, skipping.
# Data for date 2020-03-16 already in CSV, skipping.
# Error reading g980313.pdf: EOF marker not found
# Data for date 2013-05-22 already in CSV, skipping.
# Data for date 2016-03-15 already in CSV, skipping.
# Data for date 2022-04-28 already in CSV, skipping.
# Error reading g980716.pdf: EOF marker not found
# Data for date 2008-04-30 already in CSV, skipping.
# Data for date 2010-02-18 already in CSV, skipping.
# Data for date 2021-07-16 already in CSV, skipping.
# Data for date 2013-10-04 already in CSV, skipping.
# Data for date 2024-01-23 already in CSV, skipping.
# Data for date 2007-09-19 already in CSV, skipping.
# Error reading g980728.pdf: EOF marker not found
# Data for date 2006-09-08 already in CSV, skipping.
# Data for date 2016-01-29 already in CSV, skipping.
# Data for date 2013-09-05 already in CSV, skipping.
# Data for date 2009-02-19 already in CSV, skipping.
# Data for date 2024-07-31 already in CSV, skipping.
# Data for date 2014-11-19 already in CSV, skipping.
# Data for date 2007-10-31 already in CSV, skipping.
# Data for date 2010-08-10 already in CSV, skipping.
# Data for date 2017-10-31 already in CSV, skipping.
# Data for date 2016-09-21 already in CSV, skipping.
# Data for date 2019-06-20 already in CSV, skipping.
# Data for date 2018-04-27 already in CSV, skipping.
# Data for date 2010-11-05 already in CSV, skipping.
# Data for date 2014-08-08 already in CSV, skipping.
# Data for date 2012-01-24 already in CSV, skipping.
# Data for date 2021-09-22 already in CSV, skipping.
# Data for date 2014-06-13 already in CSV, skipping.
# Data for date 2020-12-18 already in CSV, skipping.
# Data for date 2015-11-19 already in CSV, skipping.
# Data for date 2010-04-30 already in CSV, skipping.
# Data for date 2011-08-04 already in CSV, skipping.
# Data for date 2006-10-31 already in CSV, skipping.
# Error reading g980116.pdf: EOF marker not found
# Error reading g991027.pdf: EOF marker not found
# Data for date 2017-03-16 already in CSV, skipping.
# Data for date 2020-07-15 already in CSV, skipping.
# Data for date 2012-10-05 already in CSV, skipping.
# Data for date 2024-03-19 already in CSV, skipping.
# Data for date 2017-09-21 already in CSV, skipping.
# Data for date 2007-07-12 already in CSV, skipping.
# Data for date 2013-01-22 already in CSV, skipping.
# Error reading g980909.pdf: EOF marker not found
# Data for date 2016-07-29 already in CSV, skipping.
# Data for date 2019-04-25 already in CSV, skipping.
# Data for date 2006-12-19 already in CSV, skipping.
# Data for date 2012-05-23 already in CSV, skipping.
# Data for date 2007-12-20 already in CSV, skipping.
# Data for date 2017-12-21 already in CSV, skipping.
# Error reading g990312.pdf: EOF marker not found
# Data for date 2023-06-16 already in CSV, skipping.
# Data for date 2009-04-30 already in CSV, skipping.
# Data for date 2006-07-14 already in CSV, skipping.
# Data for date 2008-04-09 already in CSV, skipping.
# Error reading g990716.pdf: EOF marker not found
# Data for date 2023-04-28 already in CSV, skipping.
# CSV file updated at /Users/kylenabors/Documents/Database/Training Data/boj/boj_minutes/boj_minutes.csv
