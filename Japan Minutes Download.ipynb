# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from PyPDF2 import PdfReader
import pandas as pd

# Directories
pdf_dir = "/Users/kylenabors/Documents/Database/Training Data/japan/japan_minutes/PDFs"
csv_path = "/Users/kylenabors/Documents/Database/Training Data/Japan/japan_minutes/japan_minutes.csv"

# Create PDF directory if it doesn't exist
if not os.path.exists(pdf_dir):
    os.makedirs(pdf_dir)

# Base URLs
base_url = "https://www.boj.or.jp"
main_url = f"{base_url}/en/mopo/mpmsche_minu/minu_all/index.htm"

# Get list of years
response = requests.get(main_url)
soup = BeautifulSoup(response.content, "html.parser")
year_links = soup.find_all(
    "a", href=re.compile(r"/en/mopo/mpmsche_minu/minu_\d{4}/index\.htm")
)

years = []
for link in year_links:
    year_url = base_url + link["href"]
    years.append(year_url)

# Get PDF links for each year
pdf_links = []
for year_url in years:
    response = requests.get(year_url)
    soup = BeautifulSoup(response.content, "html.parser")
    for link in soup.find_all(
        "a", href=re.compile(r"/en/mopo/mpmsche_minu/minu_\d{4}/g\d{6}\.pdf")
    ):
        pdf_link = base_url + link["href"]
        pdf_links.append(pdf_link)

# Download PDFs (only new files)
for pdf_url in pdf_links:
    pdf_filename = pdf_url.split("/")[-1]
    pdf_path = os.path.join(pdf_dir, pdf_filename)
    if os.path.exists(pdf_path):
        print(f"Skipping already downloaded file {pdf_filename}")
        continue
    response = requests.get(pdf_url)
    with open(pdf_path, "wb") as f:
        f.write(response.content)
    print(f"Downloaded {pdf_filename}")

# Read existing CSV data (if any)
if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    if "date" in existing_df.columns:
        existing_dates = set(pd.to_datetime(existing_df["date"]).dt.date)
    else:
        existing_dates = set()
else:
    existing_df = pd.DataFrame()
    existing_dates = set()

# Extract text from PDFs and extract date from filename
pdf_texts = []
for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        # Extract date from filename, format: 'gYYMMDD.pdf'
        date_match = re.match(r"g(\d{6})\.pdf", pdf_file)
        if date_match:
            date_str = date_match.group(1)
            # Parse date
            date = pd.to_datetime(date_str, format="%y%m%d").date()
        else:
            date = None  # Handle cases where the date isn't in the filename

        # Skip if date is already in existing CSV
        if date in existing_dates:
            print(f"Data for date {date} already in CSV, skipping.")
            continue

        try:
            with open(pdf_path, "rb") as f:
                reader = PdfReader(f)
                text = ""
                for page in reader.pages:
                    page_text = page.extract_text()
                    if page_text:
                        text += page_text
                pdf_texts.append({"date": date, "text": text})
        except Exception as e:
            print(f"Error reading {pdf_file}: {e}")

# Combine new data with existing data and save to CSV
new_df = pd.DataFrame(pdf_texts)
if not existing_df.empty:
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)
else:
    combined_df = new_df

# Save to CSV
combined_df.to_csv(csv_path, index=False)
print(f"CSV file updated at {csv_path}")
# Out:
# Skipping already downloaded file g240731.pdf
# Skipping already downloaded file g240614.pdf
# Skipping already downloaded file g240426.pdf
# Skipping already downloaded file g240319.pdf
# Skipping already downloaded file g240123.pdf
# Skipping already downloaded file g240731.pdf
# Skipping already downloaded file g240614.pdf
# Skipping already downloaded file g240426.pdf
# Skipping already downloaded file g240319.pdf
# Skipping already downloaded file g240123.pdf
# Skipping already downloaded file g231219.pdf
# Skipping already downloaded file g171221.pdf
# Skipping already downloaded file g171031.pdf
# Skipping already downloaded file g170921.pdf
# Skipping already downloaded file g170720.pdf
# Skipping already downloaded file g170616.pdf
# Skipping already downloaded file g170427.pdf
# Skipping already downloaded file g170316.pdf
# Skipping already downloaded file g170131.pdf
# Skipping already downloaded file g161220.pdf
# Skipping already downloaded file g161101.pdf
# Skipping already downloaded file g160921.pdf
# Skipping already downloaded file g160729.pdf
# Skipping already downloaded file g160616.pdf
# Skipping already downloaded file g160428.pdf
# Skipping already downloaded file g160315.pdf
# Skipping already downloaded file g160129.pdf
# Skipping already downloaded file g151218.pdf
# Skipping already downloaded file g151119.pdf
# Skipping already downloaded file g151030.pdf
# Skipping already downloaded file g151007.pdf
# Skipping already downloaded file g150915.pdf
# Skipping already downloaded file g150807.pdf
# Skipping already downloaded file g150715.pdf
# Skipping already downloaded file g150619.pdf
# Skipping already downloaded file g150522.pdf
# Skipping already downloaded file g150430.pdf
# Skipping already downloaded file g150408.pdf
# Skipping already downloaded file g150317.pdf
# Skipping already downloaded file g150218.pdf
# Skipping already downloaded file g150121.pdf
# Skipping already downloaded file g141219.pdf
# Skipping already downloaded file g141119.pdf
# Skipping already downloaded file g141031.pdf
# Skipping already downloaded file g141007.pdf
# Skipping already downloaded file g140904.pdf
# Skipping already downloaded file g140808.pdf
# Skipping already downloaded file g140715.pdf
# Skipping already downloaded file g140613.pdf
# Skipping already downloaded file g140521.pdf
# Skipping already downloaded file g140430.pdf
# Skipping already downloaded file g140408.pdf
# Skipping already downloaded file g140311.pdf
# Skipping already downloaded file g140218.pdf
# Skipping already downloaded file g140122.pdf
# Skipping already downloaded file g131220.pdf
# Skipping already downloaded file g131121.pdf
# Skipping already downloaded file g131031.pdf
# Skipping already downloaded file g131004.pdf
# Skipping already downloaded file g130905.pdf
# Skipping already downloaded file g130808.pdf
# Skipping already downloaded file g130711.pdf
# Skipping already downloaded file g130611.pdf
# Skipping already downloaded file g130522.pdf
# Skipping already downloaded file g130426.pdf
# Skipping already downloaded file g130404.pdf
# Skipping already downloaded file g130307.pdf
# Skipping already downloaded file g130214.pdf
# Skipping already downloaded file g130122.pdf
# Skipping already downloaded file g121220.pdf
# Skipping already downloaded file g121120.pdf
# Skipping already downloaded file g121030.pdf
# Skipping already downloaded file g121005.pdf
# Skipping already downloaded file g120919.pdf
# Skipping already downloaded file g120809.pdf
# Skipping already downloaded file g120712.pdf
# Skipping already downloaded file g120615.pdf
# Skipping already downloaded file g120523.pdf
# Skipping already downloaded file g120427.pdf
# Skipping already downloaded file g120410.pdf
# Skipping already downloaded file g120313.pdf
# Skipping already downloaded file g120214.pdf
# Skipping already downloaded file g120124.pdf
# Skipping already downloaded file g111221.pdf
# Skipping already downloaded file g111130.pdf
# Skipping already downloaded file g111116.pdf
# Skipping already downloaded file g111027.pdf
# Skipping already downloaded file g111007.pdf
# Skipping already downloaded file g110907.pdf
# Skipping already downloaded file g110804.pdf
# Skipping already downloaded file g110712.pdf
# Skipping already downloaded file g110614.pdf
# Skipping already downloaded file g110520.pdf
# Skipping already downloaded file g110428.pdf
# Skipping already downloaded file g110407.pdf
# Skipping already downloaded file g110314.pdf
# Skipping already downloaded file g110215.pdf
# Skipping already downloaded file g110125.pdf
# Skipping already downloaded file g101221.pdf
# Skipping already downloaded file g101105.pdf
# Skipping already downloaded file g101028.pdf
# Skipping already downloaded file g101005.pdf
# Skipping already downloaded file g100907.pdf
# Skipping already downloaded file g100830.pdf
# Skipping already downloaded file g100810.pdf
# Skipping already downloaded file g100715.pdf
# Skipping already downloaded file g100615.pdf
# Skipping already downloaded file g100521.pdf
# Skipping already downloaded file g100510.pdf
# Skipping already downloaded file g100430.pdf
# Skipping already downloaded file g100407.pdf
# Skipping already downloaded file g100317.pdf
# Skipping already downloaded file g100218.pdf
# Skipping already downloaded file g100126.pdf
# Skipping already downloaded file g091218.pdf
# Skipping already downloaded file g091201.pdf
# Skipping already downloaded file g091120.pdf
# Skipping already downloaded file g091030.pdf
# Skipping already downloaded file g091014.pdf
# Skipping already downloaded file g090917.pdf
# Skipping already downloaded file g090811.pdf
# Skipping already downloaded file g090715.pdf
# Skipping already downloaded file g090616.pdf
# Skipping already downloaded file g090522.pdf
# Skipping already downloaded file g090430.pdf
# Skipping already downloaded file g090407.pdf
# Skipping already downloaded file g090318.pdf
# Skipping already downloaded file g090219.pdf
# Skipping already downloaded file g090122.pdf
# Skipping already downloaded file g081219.pdf
# Skipping already downloaded file g081202.pdf
# Skipping already downloaded file g081121.pdf
# Skipping already downloaded file g081031.pdf
# Skipping already downloaded file g081014.pdf
# Skipping already downloaded file g081007.pdf
# Skipping already downloaded file g080929.pdf
# Skipping already downloaded file g080918.pdf
# Skipping already downloaded file g080917.pdf
# Skipping already downloaded file g080819.pdf
# Skipping already downloaded file g080715.pdf
# Skipping already downloaded file g080613.pdf
# Skipping already downloaded file g080520.pdf
# Skipping already downloaded file g080430.pdf
# Skipping already downloaded file g080409.pdf
# Skipping already downloaded file g080307.pdf
# Skipping already downloaded file g080215.pdf
# Skipping already downloaded file g080122.pdf
# Skipping already downloaded file g071220.pdf
# Skipping already downloaded file g071113.pdf
# Skipping already downloaded file g071031.pdf
# Skipping already downloaded file g071011.pdf
# Skipping already downloaded file g070919.pdf
# Skipping already downloaded file g070823.pdf
# Skipping already downloaded file g070712.pdf
# Skipping already downloaded file g070615.pdf
# Skipping already downloaded file g070517.pdf
# Skipping already downloaded file g070427.pdf
# Skipping already downloaded file g070410.pdf
# Skipping already downloaded file g070320.pdf
# Skipping already downloaded file g070221.pdf
# Skipping already downloaded file g070118.pdf
# Skipping already downloaded file g061219.pdf
# Skipping already downloaded file g061116.pdf
# Skipping already downloaded file g061031.pdf
# Skipping already downloaded file g061013.pdf
# Skipping already downloaded file g060908.pdf
# Skipping already downloaded file g060811.pdf
# Skipping already downloaded file g060714.pdf
# Skipping already downloaded file g060615.pdf
# CSV file updated at /Users/kylenabors/Documents/Database/Training Data/Japan/japan_minutes/japan_minutes.csv
